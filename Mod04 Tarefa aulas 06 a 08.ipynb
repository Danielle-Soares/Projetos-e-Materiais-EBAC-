# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url='https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

# %%
# 2) Seu código aqui
r=requests.get(url)

# %%
# 3) Seu código aqui
r.status_code
# Out:
# 200

# %%
data_json=r.json()

# %%
dados=pd.DataFrame(data_json['items'])
dados
# Out:
#       id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 0         30597        Município               Apucarana   4101408  PR
# 1         30974        Município                Peritiba   4212601  SC
# 2         32808        Município               Joinville   4209102  SC
# 3         33254        Município     São José do Cerrito   4216800  SC
# 4         33288        Município                  Sabará   3156700  MG
# ...         ...              ...                     ...       ...  ..
# 4995      16996        Município           Foz do Iguaçu   4108304  PR
# 4996      17000        Município    Santa Maria do Oeste   4123857  PR
# 4997      17004        Município               Rio Pardo   4315701  RS
# 4998      17012        Município             Quitandinha   4121208  PR
# 4999      17016        Município  Dom Pedro de Alcântara   4306551  RS
#
#                    num_pvl                                             status  \
# ...

# %%
pvls_rj=dados[dados['uf']=="RJ"]
pvls_rj
# Out:
#       id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 30        22824        Município          Rio de Janeiro   3304557  RJ
# 233       27100        Município          Rio de Janeiro   3304557  RJ
# 357       28822        Município                 Resende   3304201  RJ
# 769       10433        Município                Mesquita   3302858  RJ
# 771       10441        Município                 Niterói   3303302  RJ
# 1267      12078        Município                 Resende   3304201  RJ
# 1273       9308        Município             Nova Iguaçu   3303500  RJ
# 1327       6644        Município      São João de Meriti   3305109  RJ
# 1350       5689        Município               Rio Claro   3304409  RJ
# 1518       6833           Estado          Rio de Janeiro        33  RJ
# 1547      11707        Município      São João de Meriti   3305109  RJ
# 1577       5918           Estado          Rio de Janeiro        33  RJ
# ...

# %%
ano_status=dados['data_status'].str.slice(start=6,stop=10)
ano_status
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4       2019
#         ...
# 4995    2008
# 4996    2006
# 4997    2011
# 4998    2006
# 4999    2011
# Name: data_status, Length: 5000, dtype: object

# %%
ano_status.value_counts()
# Out:
# 2008    664
# 2010    445
# 2007    434
# 2006    405
# 2014    289
# 2004    281
# 2011    277
# 2009    276
# 2012    258
# 2013    246
# 2018    185
# 2016    183
# 2002    180
# 2017    173
# 2015    160
# 2022    139
# 2003    122
# 2023    104
# 2019     70
# 2005     66
# 2021     33
# 2020     10
# Name: data_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consulta_uf_municipio (uf=str,cidade=str):

    dados_uf=dados[dados['uf']==uf]
    resposta=dados_uf[dados_uf['interessado']==cidade]
    return resposta

# %%
consulta_uf_municipio('PR','Foz do Iguaçu')
# Out:
#       id_pleito tipo_interessado    interessado  cod_ibge  uf  \
# 555       12433        Município  Foz do Iguaçu   4108304  PR
# 774        7989        Município  Foz do Iguaçu   4108304  PR
# 831       15968        Município  Foz do Iguaçu   4108304  PR
# 1112      14634        Município  Foz do Iguaçu   4108304  PR
# 1119      15013        Município  Foz do Iguaçu   4108304  PR
# 2228      16693        Município  Foz do Iguaçu   4108304  PR
# 2332       9734        Município  Foz do Iguaçu   4108304  PR
# 2454      16981        Município  Foz do Iguaçu   4108304  PR
# 3503      20026        Município  Foz do Iguaçu   4108304  PR
# 3569       9157        Município  Foz do Iguaçu   4108304  PR
# 4221      17922        Município  Foz do Iguaçu   4108304  PR
# 4995      16996        Município  Foz do Iguaçu   4108304  PR
#
#                    num_pvl    status          num_processo  \
# 555                   None  Deferido  17944.001684/2014-13
# ...

# %%
# 2) Seu código aqui
consulta_MG=dados[dados['uf']=='MG']
consulta_MG=consulta_MG[consulta_MG['status']=='Arquivado por decurso de prazo']
consulta_MG
# Out:
#       id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 144        5066        Município            Bom Despacho   3107406  MG
# 340       25950        Município    São Vicente de Minas   3165305  MG
# 422       12260        Município              Cana Verde   3111903  MG
# 423       12263        Município             Divinópolis   3122306  MG
# 427       12447        Município                   Ibiaí   3129608  MG
# ...         ...              ...                     ...       ...  ..
# 4373      13255        Município  São Francisco de Sales   3161304  MG
# 4385      20953        Município                Ipatinga   3131307  MG
# 4433      26840        Município              Cana Verde   3111903  MG
# 4607      13320        Município           Montes Claros   3143302  MG
# 4843       5604        Município                Serranos   3167004  MG
#
#                    num_pvl                          status  \
# ...

# %%
# 3) Seu código aqui
consulta_BA=dados[dados['uf']=='BA']
consulta_BA=consulta_BA[consulta_BA['status']=='Deferido']
consulta_BA
# Out:
#       id_pleito tipo_interessado       interessado  cod_ibge  uf  \
# 48        22966        Município          Salvador   2927408  BA
# 82        13003        Município            Caculé   2905008  BA
# 145        5090        Município  Cardeal da Silva   2907004  BA
# 154        7496        Município        Carinhanha   2907103  BA
# 249       12617        Município           Caetité   2905206  BA
# ...         ...              ...               ...       ...  ..
# 4719      41920        Município             Irecê   2914604  BA
# 4805      31108        Município          Salvador   2927408  BA
# 4815      63946        Município       Sátiro Dias   2929701  BA
# 4950      60890        Município             Cairu   2905404  BA
# 4963       7404        Município           Lençóis   2919306  BA
#
#                    num_pvl    status          num_processo  \
# 48    PVL02.000016/2016-78  Deferido  17944.000905/2016-06
# 82                    None  Deferido  17944.001881/2006-22
# ...

# %%
# 4) Seu código aqui
consulta_BA.to_csv('consulta_Bahia.csv')
